# %%
import pandas as pd
import numpy as np

# %% [markdown]
# # 전체 직군 stack, 우대사항 합본 생성

# %%
prefer = pd.read_csv("data/원티드_채용공고_합본.csv")
prefer
# Out:
#          company       job_name city             stack  NCS_code  \
# 0            이노팸      머신러닝 엔지니어   서울              Java  20010701
# 1            이노팸      머신러닝 엔지니어   서울              Java  20010706
# 2            이노팸      머신러닝 엔지니어   서울            Python  20010701
# 3            이노팸      머신러닝 엔지니어   서울            Python  20010706
# 4      루닛(Lunit)      머신러닝 엔지니어   서울           Pytorch  20010701
# ...          ...            ...  ...               ...       ...
# 16156    워트인텔리전스  데이터 엔지니어(DBA)   서울     ElasticSearch  20010209
# 16157    워트인텔리전스  데이터 엔지니어(DBA)   서울     ElasticSearch  20010211
# 16158    워트인텔리전스  데이터 엔지니어(DBA)   서울  Spring Framework  20010204
# 16159    워트인텔리전스  데이터 엔지니어(DBA)   서울  Spring Framework  20010209
# 16160    워트인텔리전스  데이터 엔지니어(DBA)   서울  Spring Framework  20010211
#
#                                      link     no
# 0      https://www.wanted.co.kr/wd/183398      1
# 1      https://www.wanted.co.kr/wd/183398      2
# 2      https://www.wanted.co.kr/wd/183398      3
# 3      https://www.wanted.co.kr/wd/183398      4
# 4      https://www.wanted.co.kr/wd/183295      5
# ...                                   ...    ...
# 16156   https://www.wanted.co.kr/wd/26823  16157
# 16157   https://www.wanted.co.kr/wd/26823  16158
# 16158   https://www.wanted.co.kr/wd/26823  16159
# 16159   https://www.wanted.co.kr/wd/26823  16160
# 16160   https://www.wanted.co.kr/wd/26823  16161
#
# [16161 rows x 7 columns]

# %%
# 민혁님 크롤링
DBA = pd.read_csv("data/wanted_crawling_DBA_pre.csv") # DE 로 통일
DE = pd.read_csv("data/wanted_crawling_DE_pre.csv") # DE 로 통일
MLE = pd.read_csv("data/wanted_crawling_MLE_pre.csv")

# %%
# 제욱 크롤링
BigData_ENG = pd.read_csv("data/BigData_ENG.csv") # DE 로 통일
Data_ANL = pd.read_csv("data/Data_ANL.csv")
Data_SCI = pd.read_csv("data/Data_SCI.csv")

# %%
MLE
# Out:
#                                                  stack  \
# 0                                                  NaN
# 1                                             C++\nROS
# 2    Git\nDjango\nPytorch\nHTML\nJavaScript\nPython...
# 3                                                  NaN
# 4                          Pytorch\nTensorflow\nPython
# ..                                                 ...
# 374                                             Docker
# 375                           Git\nPython\nAWS\nDocker
# 376                                                NaN
# 377  Android\niOS\nJava\nJavaScript\nPython\nTypeSc...
# 378                                                NaN
#
#                                             preference region
# 0                                                  NaN    NaN
# 1    • 석사 이상의 학력 혹은 3년 이상의 경력\n• 모션 제어, 최적 제어, 경로 생...  인천.한국
# 2    • R&D, 납품 용역 과제 수행 및 관리 경험\n• AI 관련 석사학위 이상의 연...  대전.한국
# 3    1) 영상 등 다양한 데이터를 많이 다뤄 보신 분\n2) Mobile/Embedde...  경기.한국
# 4    • 분산 학습 시스템을 개발한 경험\n• 기계학습 분야에서 좋은 연구 트랙 레코드를...  서울.한국
# ..                                                 ...    ...
# 374  • CSE 관련 전공자\n• 자신의 기술에 대해 설명이 가능한 정도의 영어\n• 머...  서울.한국
# 375  • 이공계 석사 이상 학위 보유자\n• 의료/보건 통계 관련 기초 지식 보유 또는 ...  서울.한국
# 376  - 데이터 사이언스 관련 전공자\n- 퍼블릭 클라우드 환경 (GCP, AWS, Az...  서울.한국
# 377  - 인공지능 업계 경험\n- 머신러닝 관련 분야의 석/박사 학위 또는 그에 준하는 ...  서울.한국
# 378  • 관련 딥러닝 모델 연구/개발자 우대(Tensor Flow, PyTouch)\n•...  서울.한국
#
# [379 rows x 3 columns]

# %% [markdown]
# - 컬럼명 민혁님 컬럼과 통일

# %%
BigData_ENG = BigData_ENG.drop(columns = ['company', 'url'])
Data_ANL = Data_ANL.drop(columns = ['company', 'url'])
Data_SCI = Data_SCI.drop(columns = ['company', 'url'])

# %%
BigData_ENG = BigData_ENG[['tool', 'prefer', 'location']]
Data_ANL = Data_ANL[['tool', 'prefer', 'location']]
Data_SCI = Data_SCI[['tool', 'prefer', 'location']]

# %%
BigData_ENG.columns = ['stack', 'preference', 'region']
Data_ANL.columns = ['stack', 'preference', 'region']
Data_SCI.columns = ['stack', 'preference', 'region']

# %%
BigData_ENG.head(2)
# Out:
#                                                stack  \
# 0  Confluence\nGit\nGitLab\nJIRA\nPython\nSQL\nNL...
# 1  Git\nDjango\nPytorch\nHTML\nJavaScript\nPython...
#
#                                           preference region
# 0  • 금융 도메인 경험이 있으신 분\n• 주식 투자에 대한 관심과 경험이 있으신 분\...  서울.한국
# 1  • R&D, 납품 용역 과제 수행 및 관리 경험\n• AI 관련 석사학위 이상의 연...  대전.한국

# %% [markdown]
# - DBA, 데이터 엔지니어, 빅데이터 엔지니어 -> 데이터 엔지니어 직군 하나로 통일

# %%
DE = pd.concat([DBA, DE, BigData_ENG], ignore_index = True)
DE
# Out:
#                                                  stack  \
# 0                                                  NaN
# 1            MySQL\nAWS\nScripting\n서버\nNoSQL\n네트워크 개발
# 2                  데이터베이스\nC++\nWindows 서버\nSTL\nMSSQL
# 3    Git\nLinux\nReact\nJavaScript\nSQL\nSpring Fra...
# 4                                    MySQL\nPostgreSQL
# ..                                                 ...
# 604  MySQL\nOracle\nReact\nJava\nJavaScript\nKotlin...
# 605                                                NaN
# 606  MySQL\nOracle\nReact\nJava\nJavaScript\nKotlin...
# 607                                                NaN
# 608                                                NaN
#
#                                             preference region
# 0                                                  NaN    NaN
# 1    • 기본적인 수준의 Script언어 능력\n• 클라우드 환경 운영(AWS, NAVE...  서울.한국
# 2    • 게임 DB 개발 경험 있으신 분\n• 상용 게임 오픈 경력 있으신 분\n• Mo...  서울.한국
# 3       • 금융업무 경험자\n• 대용량 데이타 마이그레이션 경험자\n• 대규모 트래픽 처리  서울.한국
# 4    • DBA경력 1년 이상\n• 관련 학과 졸업\n• DB 관련 교육 기관 수료\n•...  서울.한국
# ..                                                 ...    ...
# 604  - Full-Stack 개발자\n- 검색엔진으로 서비스 진행 경험\n- 유지보수를 ...  서울.한국
# 605  - 이기종 데이터베이스 마이그레이션 경험이 있으신 분\n- 대용량 트래픽 처리를 위...  서울.한국
# 606  - 대량의 데이터를 파이프라인으로 다뤄본 경험\n- 검색엔진을 다뤄본 경험\n- 데...  서울.한국
# 607  • Big Data 관련 개발 경험 및 관련 Open Source 사용 경험\n• ...  서울.한국
# 608  • Hadoop 및 Hadoop Eco 활용 가능자( hdfs, Spark, Hiv...  서울.한국
#
# [609 rows x 3 columns]

# %% [markdown]
# - 전체 직군 통합 stack, 우대사항 추출을 위해 concat 하여 하나의 DF생성

# %%
all_pre = pd.concat([DE, MLE, Data_ANL, Data_SCI], ignore_index = True)
all_pre
# Out:
#                                                   stack  \
# 0                                                   NaN
# 1             MySQL\nAWS\nScripting\n서버\nNoSQL\n네트워크 개발
# 2                   데이터베이스\nC++\nWindows 서버\nSTL\nMSSQL
# 3     Git\nLinux\nReact\nJavaScript\nSQL\nSpring Fra...
# 4                                     MySQL\nPostgreSQL
# ...                                                 ...
# 1380                           Git\nPython\nAWS\nDocker
# 1381                                                NaN
# 1382                                                NaN
# 1383                                                NaN
# 1384                                                NaN
#
#                                              preference region
# 0                                                   NaN    NaN
# 1     • 기본적인 수준의 Script언어 능력\n• 클라우드 환경 운영(AWS, NAVE...  서울.한국
# 2     • 게임 DB 개발 경험 있으신 분\n• 상용 게임 오픈 경력 있으신 분\n• Mo...  서울.한국
# 3        • 금융업무 경험자\n• 대용량 데이타 마이그레이션 경험자\n• 대규모 트래픽 처리  서울.한국
# 4     • DBA경력 1년 이상\n• 관련 학과 졸업\n• DB 관련 교육 기관 수료\n•...  서울.한국
# ...                                                 ...    ...
# 1380  • 이공계 석사 이상 학위 보유자\n• 의료/보건 통계 관련 기초 지식 보유 또는 ...  서울.한국
# 1381  [이런 분이라면 더 좋아요!]\n• AWS/GCP 등 클라우드 환경에서 데이터 플랫...  경기.한국
# 1382  - 데이터 사이언스 관련 전공자\n- 퍼블릭 클라우드 환경 (GCP, AWS, Az...  서울.한국
# 1383  • ML 관련 Top-tier 학회 및 저널 Publication 실적\n(Neur...  서울.한국
# 1384                                                NaN    NaN
#
# [1385 rows x 3 columns]

# %% [markdown]
# - 지역 확인

# %%
all_pre['region'] = all_pre['region'].str.slice(0, 2)
all_pre
# Out:
#                                                   stack  \
# 0                                                   NaN
# 1             MySQL\nAWS\nScripting\n서버\nNoSQL\n네트워크 개발
# 2                   데이터베이스\nC++\nWindows 서버\nSTL\nMSSQL
# 3     Git\nLinux\nReact\nJavaScript\nSQL\nSpring Fra...
# 4                                     MySQL\nPostgreSQL
# ...                                                 ...
# 1380                           Git\nPython\nAWS\nDocker
# 1381                                                NaN
# 1382                                                NaN
# 1383                                                NaN
# 1384                                                NaN
#
#                                              preference region
# 0                                                   NaN    NaN
# 1     • 기본적인 수준의 Script언어 능력\n• 클라우드 환경 운영(AWS, NAVE...     서울
# 2     • 게임 DB 개발 경험 있으신 분\n• 상용 게임 오픈 경력 있으신 분\n• Mo...     서울
# 3        • 금융업무 경험자\n• 대용량 데이타 마이그레이션 경험자\n• 대규모 트래픽 처리     서울
# 4     • DBA경력 1년 이상\n• 관련 학과 졸업\n• DB 관련 교육 기관 수료\n•...     서울
# ...                                                 ...    ...
# 1380  • 이공계 석사 이상 학위 보유자\n• 의료/보건 통계 관련 기초 지식 보유 또는 ...     서울
# 1381  [이런 분이라면 더 좋아요!]\n• AWS/GCP 등 클라우드 환경에서 데이터 플랫...     경기
# 1382  - 데이터 사이언스 관련 전공자\n- 퍼블릭 클라우드 환경 (GCP, AWS, Az...     서울
# 1383  • ML 관련 Top-tier 학회 및 저널 Publication 실적\n(Neur...     서울
# 1384                                                NaN    NaN
#
# [1385 rows x 3 columns]

# %%
all_pre['region'].value_counts()
# Out:
# 서울    1170
# 경기     167
# 대전      17
# 인천      14
# 부산       3
# 경남       2
# 대구       1
# 충남       1
# 제주       1
# Name: region, dtype: int64

# %% [markdown]
# - stack 추출

# %%
# stack이 nan아닌 값 추출, 개행문자 제거
stacks = all_pre.loc[~(all_pre['stack'].isnull()), 'stack'].str.split('\n', regex=True)
stacks
# Out:
# 1             [MySQL, AWS, Scripting, 서버, NoSQL, 네트워크 개발]
# 2                   [데이터베이스, C++, Windows 서버, STL, MSSQL]
# 3       [Git, Linux, React, JavaScript, SQL, Spring Fr...
# 4                                     [MySQL, PostgreSQL]
# 5       [Git, Github, MongoDB, MySQL, Pytorch, Scikit-...
#                               ...
# 1376                         [Git, Python, SQL, AWS, GCP]
# 1377    [Android, GraphQL, iOS, JavaScript, TypeScript...
# 1378                                 [Linux, Python, AWS]
# 1379               [Git, MySQL, Redis, Node.js, AWS, GCP]
# 1380                           [Git, Python, AWS, Docker]
# Name: stack, Length: 919, dtype: object

# %%
# 하나의 리스트 형식으로 저장
stack_list = []
for i in stacks:
    for j in i:
        stack_list.append(j)
stack_list
# Out:
# ['MySQL',
#  'AWS',
#  'Scripting',
#  '서버',
#  'NoSQL',
#  '네트워크 개발',
#  '데이터베이스',
#  'C++',
#  'Windows 서버',
#  'STL',
#  'MSSQL',
#  'Git',
#  'Linux',
#  'React',
#  'JavaScript',
#  'SQL',
#  'Spring Framework',
#  'MySQL',
#  'PostgreSQL',
#  'Git',
#  'Github',
#  'MongoDB',
#  'MySQL',
#  'Pytorch',
#  'Scikit-Learn',
#  'JavaScript',
#  'Node.js',
#  'R',
#  'SQL',
#  'AWS',
#  'Jenkins',
#  'NoSQL',
#  'Apache',
#  'Docker',
#  'JUnit',
#  'MSSQL',
#  'Kubernetes',
#  'MySQL',
#  'PostgreSQL',
#  'React',
#  'Spring Framework',
#  'Pytorch',
#  'Tensorflow',
#  'C / C++',
#  'Java',
#  'Python',
#  'GIS',
#  'OpenCV',
#  '네비게이션 시스템',
#  'GIS 시스템',
#  'GIS 응용 프로그램',
#  'Oracle',
#  'SQL',
#  'Azure',
#  'Java',
#  'Python',
#  'Scala',
#  'AWS',
#  'Docker',
#  'GCP',
#  'Kubernetes',
#  'SAP',
#  'Java',
#  'JSP',
#  'JSP 개발',
#  'MMO',
#  '기술 관리',
#  '프로젝트 관리',
#  'RPG',
#  '모바일 게임',
#  'MySQL',
#  'Java',
#  'JavaScript',
#  'Python',
#  'SQL',
#  'AWS',
#  'Spring Boot',
#  'Restful API',
#  'MySQL',
#  'SQL',
#  'SQL 튜닝',
#  'Java',
#  'Spring Framework',
#  'React.js',
#  'Vue.JS',
#  'iOS',
#  'HTML',
#  'JavaScript',
#  'SQL',
#  'API',
#  'DSL',
#  'SAP',
#  'BI',
#  'Git',
#  'Android',
#  'iOS',
#  'Linux',
#  'MySQL',
#  'React',
#  'VueJS',
#  'C#',
#  'PHP',
#  'TypeScript',
#  'AWS',
#  'Spring Framework',
#  'React.js',
#  'React',
#  'Spring Framework',
#  'Github',
#  'MySQL',
#  'Java',
#  'AWS',
#  'JUnit',
#  'Spring Framework',
#  'Spring Boot',
#  'MySQL',
#  'Python',
#  'Shell',
#  'Puppet',
#  'Data Guard',
#  'Java',
#  'Python',
#  'MSSQL',
#  'Python',
#  'SQL',
#  'Google Analytics',
#  'MySQL',
#  'SQL',
#  'AWS',
#  'DirectX',
#  'C',
#  'C++',
#  'Git',
#  '데이터 분석',
#  'MSSQL',
#  'GitLab',
#  'MongoDB',
#  'React',
#  'Node.js',
#  'AWS',
#  'Java',
#  'API',
#  'RDBMS',
#  'SSO',
#  'JIRA',
#  'Azure',
#  'Linux',
#  'MySQL',
#  'JavaScript',
#  'Shell',
#  'AWS',
#  'MSSQL',
#  'GitLab',
#  'MongoDB',
#  'React',
#  'Node.js',
#  'AWS',
#  'Git',
#  'GitLab',
#  'ExpressJS',
#  'Linux',
#  'MySQL',
#  'Oracle',
#  'Redis',
#  'VueJS',
#  'Java',
#  'JavaScript',
#  'PHP',
#  'Python',
#  'Jenkins',
#  'Docker',
#  'Tomcat',
#  'SVN',
#  'SSL',
#  'ElasticSearch',
#  'NodeJS',
#  'Spring Framework',
#  'JPA',
#  'Nginx',
#  'RabbitMQ',
#  'Apache 2',
#  'ES6',
#  '방화벽',
#  '정보 보안',
#  'CISSP',
#  'IPS',
#  'CISA',
#  '백신',
#  'DLP',
#  'MySQL',
#  'Java',
#  'Kotlin',
#  'Rust',
#  'Scala',
#  'AWS',
#  'Go',
#  'Golang',
#  'Apache Kafka',
#  'Spring Boot',
#  'Kubernetes',
#  'Git',
#  'Firebase',
#  'MySQL',
#  'React',
#  'CSS',
#  'HTML',
#  'JavaScript',
#  'Node.js',
#  'PHP',
#  'TypeScript',
#  'AWS',
#  'NoSQL',
#  'Bootstrap',
#  'SASS',
#  'Flutter',
#  'Notion',
#  'Next.js',
#  'Restful API',
#  'Oracle',
#  'Java',
#  'PostgreSQL',
#  'Spring Framework',
#  'Spring Boot',
#  'Restful API',
#  'MySQL',
#  'Oracle',
#  'SQL',
#  'PostgreSQL',
#  'GitLab',
#  'CSS',
#  'TypeScript',
#  'React.js',
#  'Next.js',
#  'Azure',
#  'MySQL',
#  'Java',
#  'AWS',
#  'Docker',
#  'ElasticSearch',
#  'Spring Framework',
#  'React',
#  'CSS',
#  'TypeScript',
#  'UX',
#  'UI 디자인',
#  'ES6',
#  'Redux',
#  'Next.js',
#  'React',
#  'Spring Framework',
#  'Python',
#  'SQL',
#  'Google Analytics',
#  '서비스 관리',
#  '시스템 관리',
#  'Linux',
#  'AWS',
#  'VPN',
#  'CentOS',
#  'Ubuntu',
#  'Git',
#  'Github',
#  'Pytorch',
#  'Tensorflow',
#  'Python',
#  'SQL',
#  'AWS',
#  'Docker',
#  'PostgreSQL',
#  'Kubernetes',
#  'Android',
#  '.NET',
#  'iOS',
#  'Linux',
#  'MySQL',
#  'Spark',
#  'C / C++',
#  'HTML',
#  'Java',
#  'ObjectiveC',
#  'Python',
#  'SQL',
#  'Swift',
#  'Agile',
#  'AWS',
#  'C++',
#  'VM웨어',
#  'DevOps',
#  'Jenkins',
#  'Mac',
#  'PMP',
#  'Citrix',
#  'CISA',
#  'OpenStack',
#  'Xamarin',
#  'Xen',
#  '영어 실력',
#  'OSS',
#  'Kubernetes',
#  'Android',
#  '.NET',
#  'iOS',
#  'Linux',
#  'MySQL',
#  'Spark',
#  'C / C++',
#  'HTML',
#  'Java',
#  'ObjectiveC',
#  'Python',
#  'SQL',
#  'Swift',
#  'Agile',
#  'AWS',
#  'C++',
#  'VM웨어',
#  'DevOps',
#  'Jenkins',
#  'Mac',
#  'PMP',
#  'Citrix',
#  'CISA',
#  'OpenStack',
#  'Xamarin',
#  'Xen',
#  '영어 실력',
#  'OSS',
#  'Kubernetes',
#  'Android',
#  '.NET',
#  'iOS',
#  'Linux',
#  'MySQL',
#  'Spark',
#  'C / C++',
#  'HTML',
#  'Java',
#  'ObjectiveC',
#  'Python',
#  'SQL',
#  'Swift',
#  'Agile',
#  'AWS',
#  'C++',
#  'VM웨어',
#  'DevOps',
#  'Jenkins',
#  'Mac',
#  'PMP',
#  'Citrix',
#  'CISA',
#  'OpenStack',
#  'Xamarin',
#  'Xen',
#  '영어 실력',
#  'OSS',
#  'Kubernetes',
#  'Delphi',
#  'Java',
#  'SQL',
#  'ERP 소프트웨어',
#  '서비스 관리',
#  '시스템 관리',
#  'Python',
#  'React',
#  'AWS',
#  'GIS',
#  'Spring Boot',
#  'BitBucket',
#  'Confluence',
#  'Git',
#  'Slack',
#  'Android',
#  'ExpressJS',
#  'iOS',
#  'MongoDB',
#  'MySQL',
#  'Redis',
#  'VueJS',
#  'C#',
#  'JavaScript',
#  'Kotlin',
#  'Python',
#  'SQL',
#  'Swift',
#  'TypeScript',
#  'C',
#  'AWS',
#  'CRM',
#  'HTML5',
#  'CSS3',
#  'NodeJS',
#  'Spring Framework',
#  'Rx',
#  'React.js',
#  'React Native',
#  'Git',
#  'Java',
#  'REST',
#  'NoSQL',
#  'Spring Framework',
#  'IntelliJ IDEA',
#  'Visual Studio Code',
#  'SAP',
#  'ABAP',
#  'SAP ERP',
#  'DirectX',
#  'C',
#  'C++',
#  'Java',
#  'JavaScript',
#  'Spring Boot',
#  'Git',
#  'Github',
#  'Android',
#  'iOS',
#  'MySQL',
#  'React',
#  'HTML',
#  'JavaScript',
#  'Python',
#  'AWS',
#  'Bootstrap',
#  'EC2',
#  'NodeJS',
#  'Spring Framework',
#  'React Native',
#  'Spring Boot',
#  'AWS',
#  'DevOps',
#  'Docker',
#  'GCP',
#  'AWS',
#  'DevOps',
#  'Docker',
#  'GCP',
#  'Linux',
#  'Python',
#  'Golang',
#  'Restful API',
#  'React',
#  'Node.js',
#  'AWS',
#  'React.js',
#  'React Native',
#  'Next.js',
#  'Nest.js',
#  'VueJS',
#  'CSS',
#  'JavaScript',
#  'TypeScript',
#  'React.js',
#  'Git',
#  'MySQL',
#  'React',
#  'JavaScript',
#  'Python',
#  'SQL',
#  'AWS',
#  'ES6',
#  'Next.js',
#  'Linux',
#  '보안',
#  '인프라',
#  '정보 보안',
#  'Windows 서버',
#  '정보관리',
#  'NAS',
#  '솔루션 개발',
#  '백신',
#  'DLP',
#  '보안 정책',
#  '보안 관리',
#  '보안 교육',
#  'Git',
#  '데이터 분석',
#  'MSSQL',
#  'React',
#  'Spring Framework',
#  'VueJS',
#  'Python',
#  'SQL',
#  'AWS',
#  '리팩토링',
#  '백엔드 개발',
#  'Spring Boot',
#  'React',
#  'HTML',
#  'JavaScript',
#  'Git',
#  'Hadoop',
#  'Linux',
#  'MySQL',
#  'Oracle',
#  'C / C++',
#  'Python',
#  'SQL',
#  '데이터베이스',
#  'UNIX',
#  '복제',
#  'MSSQL',
#  'Git',
#  'Python',
#  'AWS',
#  'Spring Framework',
#  'Apache Spark',
#  'MongoDB',
#  'Redis',
#  'SQL',
#  'Shell Scripting',
#  'PostgreSQL',
#  'CentOS',
#  'API',
#  'UX',
#  'C#',
#  'Java',
#  'Azure',
#  'Memcached',
#  'Redis',
#  'JavaScript',
#  'Node.js',
#  'Python',
#  'TypeScript',
#  'AWS',
#  'HTML5',
#  'ETL',
#  'GCP',
#  'React Native',
#  'Git',
#  'MySQL',
#  'Java',
#  'SQL',
#  'Spring Framework',
#  'JPA',
#  'Spring Boot',
#  'Flask',
#  'MongoDB',
#  'Node.js',
#  'Python',
#  'AWS',
#  '페르소나',
#  'Github',
#  'Pytorch',
#  'Tensorflow',
#  'Python',
#  '딥 러닝',
#  'NLP',
#  'AWS',
#  '모델링',
#  '데이터 분석',
#  '인공 지능',
#  'GCP',
#  '자연 언어 처리',
#  '클라우드 응용 프로그램',
#  '모델링 및 시뮬레이션',
#  'ML',
#  'MySQL',
#  'Python',
#  'Git',
#  'AngularJS',
#  'React',
#  'JavaScript',
#  'Node.js',
#  'Python',
#  'AWS',
#  'Docker',
#  'Git',
#  'AngularJS',
#  'React',
#  'JavaScript',
#  'Node.js',
#  'Python',
#  'AWS',
#  'Docker',
#  'React',
#  'Azure',
#  'Pytorch',
#  'Scikit-Learn',
#  'Tensorflow',
#  'AWS',
#  'GCP',
#  'Kotlin',
#  'Node.js',
#  'TypeScript',
#  'AWS',
#  'PostgreSQL',
#  'Kubernetes',
#  'Google Cloud Platform',
#  'Python',
#  '기계 학습 (Machine Learning)',
#  'NLP',
#  'AWS',
#  '인공 지능',
#  '자연 언어 처리',
#  'Kotlin',
#  'Node.js',
#  'TypeScript',
#  'AWS',
#  'PostgreSQL',
#  'Kubernetes',
#  'MySQL',
#  'AWS',
#  'Scripting',
#  '서버',
#  'NoSQL',
#  '네트워크 개발',
#  'Redis',
#  'Java',
#  'Kotlin',
#  'C++',
#  'DevOps',
#  'Docker',
#  'ElasticSearch',
#  'Golang',
#  'Kubernetes',
#  '데이터베이스',
#  'C++',
#  'Windows 서버',
#  'STL',
#  'MSSQL',
#  'SAP',
#  'Android',
#  'iOS',
#  'MySQL',
#  'React',
#  'Java',
#  'JavaScript',
#  'Kotlin',
#  'Python',
#  'AWS',
#  'Product Management ',
#  'Spring Framework',
#  'GCP',
#  'SAP SD',
#  'SAP MM',
#  'SAP FI',
#  'Python',
#  'SAP',
#  'Android',
#  'iOS',
#  'MySQL',
#  'React',
#  'Java',
#  'JavaScript',
#  'Kotlin',
#  'Python',
#  'AWS',
#  'Product Management ',
#  'Spring Framework',
#  'GCP',
#  'SAP SD',
#  'SAP MM',
#  'SAP FI',
#  'Git',
#  'Linux',
#  'Python',
#  'AWS',
#  'Active Directory',
#  'DLP',
#  'EPM',
#  'Git',
#  'Github',
#  'Python',
#  'Docker',
#  'PostgreSQL',
#  'OpenGL',
#  'Java',
#  'AWS',
#  'RDBMS',
#  'Git',
#  'Github',
#  'MongoDB',
#  'MySQL',
#  'Pytorch',
#  'Scikit-Learn',
#  'JavaScript',
#  'Node.js',
#  'R',
#  'SQL',
#  'AWS',
#  'Jenkins',
#  'NoSQL',
#  'Apache',
#  'Docker',
#  'JUnit',
#  'MSSQL',
#  'Kubernetes',
#  'SAP',
#  'Git',
#  'JIRA',
#  'Android',
#  'iOS',
#  'Linux',
#  'MySQL',
#  'Oracle',
#  'React',
#  'HTML',
#  'Java',
#  'JavaScript',
#  'Node.js',
#  'Python',
#  'R',
#  'SQL',
#  'TypeScript',
#  'BI',
#  'AWS',
#  'SQL 서버',
#  'REST',
#  'API',
#  'DevOps',
#  'API',
#  '데이터 분석',
#  '데이터 과학',
#  'PostgreSQL',
#  'Spring Framework',
#  'DLP',
#  '프론트엔드 개발자',
#  '백엔드 개발',
#  'iBatis',
#  'ML',
#  'CSS',
#  'HTML',
#  'JavaScript',
#  'REST',
#  'HTTP',
#  'React',
#  'VueJS',
#  'TypeScript',
#  'HTML5',
#  'CSS3',
#  'Angular',
#  'BitBucket',
#  'Confluence',
#  'Git',
#  'JIRA',
#  'Pytorch',
#  'Tensorflow',
#  'Python',
#  'C',
#  'Go',
#  'C++',
#  'Docker',
#  'Golang',
#  'Atlassian JIRA',
#  'OpenCV',
#  'Python',
#  'R',
#  'Power BI',
#  'Tableau',
#  'Git',
#  'MySQL',
#  'Java',
#  'Jenkins',
#  'Spring Framework',
#  'JPA',
#  'Android',
#  'Linux',
#  'Java',
#  'SQL',
#  'iOS 개발',
#  '백엔드 개발',
#  'Google Cloud Platform',
#  'MySQL',
#  'Python',
#  'SQL',
#  'AWS',
#  'Pytorch',
#  'Scikit-Learn',
#  'Tensorflow',
#  'Azure',
#  'Java',
#  'Python',
#  'Scala',
#  'AWS',
#  'Docker',
#  'GCP',
#  'Kubernetes',
#  'Python',
#  'R',
#  'SAS',
#  'SPSS',
#  'Git',
#  'Linux',
#  'Pytorch',
#  'Python',
#  'SAP',
#  'Android',
#  'iOS',
#  'MySQL',
#  'React',
#  'Java',
#  'JavaScript',
#  'Kotlin',
#  'Python',
#  'AWS',
#  'Product Management ',
#  'Spring Framework',
#  'GCP',
#  'SAP SD',
#  'SAP MM',
#  'SAP FI',
#  'Git',
#  'Python',
#  'AWS',
#  'Spring Framework',
#  'Apache Spark',
#  'Github',
#  'JavaScript',
#  'Python',
#  'SQL',
#  'NLP',
#  'Google Analytics',
#  'MS 오피스',
#  'API',
#  'ElasticSearch',
#  'Spring Framework',
#  'Pytorch',
#  'React',
#  'Tensorflow',
#  'HTML',
#  'JavaScript',
#  'Python',
#  'TypeScript',
#  'AWS',
#  'Pytorch',
#  'React',
#  'Tensorflow',
#  'HTML',
#  'JavaScript',
#  'Python',
#  'TypeScript',
#  'AWS',
#  'Pytorch',
#  'React',
#  'Tensorflow',
#  'HTML',
#  'JavaScript',
#  'Python',
#  'TypeScript',
#  'AWS',
#  'Pytorch',
#  'React',
#  'Tensorflow',
#  'HTML',
#  'JavaScript',
#  'Python',
#  'TypeScript',
#  'AWS',
#  'ObjectiveC',
#  'Swift',
#  'Leadership',
#  '팀 빌딩',
#  'AWS',
#  '프로그램 관리',
#  '시스템 구조',
#  '팀 관리',
#  '리더십 개발',
#  'iOS 개발',
#  'iOS 디자인',
#  'Pytorch',
#  'Tensorflow',
#  'Java',
#  'Python',
#  'SQL',
#  'C++',
#  '3D',
#  'Python',
#  'C++',
#  'Python',
#  'R',
#  'SAS',
#  'SPSS',
#  'Python',
#  'SQL',
#  'Confluence',
#  'Git',
#  'ObjectiveC',
#  'Python',
#  'Swift',
#  'MVVM',
#  'Apple Software',
#  'React Native',
#  'Figma',
#  'Restful API',
#  'Azure',
#  'Java',
#  'Python',
#  'Scala',
#  'AWS',
#  'Docker',
#  'GCP',
#  'Kubernetes',
#  'Git',
#  'Linux',
#  'MySQL',
#  'Oracle',
#  'HTML',
#  'Java',
#  'JavaScript',
#  'Python',
#  'AWS',
#  'SVN',
#  'Spring Framework',
#  'MSSQL',
#  'Git',
#  'Linux',
#  'MySQL',
#  'Oracle',
#  'HTML',
#  'Java',
#  'JavaScript',
#  'Python',
#  'AWS',
#  'SVN',
#  'Spring Framework',
#  'MSSQL',
#  'SAP',
#  'Java',
#  'JSP',
#  'JSP 개발',
#  'OpenGL',
#  'Java',
#  'AWS',
#  'RDBMS',
#  'iOS',
#  'Java',
#  'Node.js',
#  'Python',
#  'C++',
#  'API',
#  'NodeJS',
#  'SAP',
#  'Android',
#  'iOS',
#  'MySQL',
#  'React',
#  'Java',
#  'JavaScript',
#  'Kotlin',
#  'Python',
#  'AWS',
#  'Product Management ',
#  'Spring Framework',
#  'GCP',
#  'SAP SD',
#  'SAP MM',
#  'SAP FI',
#  'MySQL',
#  'React',
#  'HTML',
#  'JavaScript',
#  'AWS',
#  'Spring Framework',
#  'Confluence',
#  'JIRA',
#  'JSF',
#  'MySQL',
#  'React',
#  'JavaScript',
#  'AWS',
#  'Docker',
#  'Spring Framework',
#  'JPA',
#  'Git',
#  'React',
#  'JavaScript',
#  'TypeScript',
#  'HTML5',
#  'CSS3',
#  'Svelte',
#  'Vue.JS',
#  'Linux',
#  'Python',
#  'Golang',
#  'Restful API',
#  'Confluence',
#  'JIRA',
#  'Agile',
#  '개발',
#  'Processing',
#  'Product Management ',
#  'QA 엔지니어링',
#  'Github',
#  'JavaScript',
#  'Python',
#  'SQL',
#  'NLP',
#  'Google Analytics',
#  'MS 오피스',
#  'API',
#  'ElasticSearch',
#  'Spring Framework',
#  'MySQL',
#  'Java',
#  'Kotlin',
#  'AWS',
#  'Kubernetes',
#  'MySQL',
#  'Python',
#  'SQL',
#  ...]

# %%
# 데이터프레임 형식으로 변환
stacks_count = pd.DataFrame(pd.Series(data=stack_list).value_counts()).reset_index()
stacks_count
# Out:
#                     index    0
# 0                  Python  517
# 1                     AWS  355
# 2                     Git  218
# 3              JavaScript  192
# 4                    Java  187
# ..                    ...  ...
# 437              소프트웨어 공학    1
# 438                컴퓨터 공학    1
# 439  RESTful Architecture    1
# 440                   OOP    1
# 441          WebSphere MQ    1
#
# [442 rows x 2 columns]

# %%
stacks_count.columns= ['stack', 'count']
stacks_count['stack'].unique()
# Out:
# array(['Python', 'AWS', 'Git', 'JavaScript', 'Java', 'SQL', 'React',
#        'MySQL', 'Docker', 'Pytorch', 'TypeScript', 'Linux', 'Github',
#        'Spring Framework', 'Tensorflow', 'C++', 'Node.js', 'HTML',
#        'PostgreSQL', 'Kubernetes', 'Kotlin', 'Android', 'JIRA', 'GCP',
#        'CSS', 'iOS', 'C / C++', 'Swift', 'MongoDB', 'C', 'Next.js',
#        'Azure', 'React.js', 'Spark', 'ElasticSearch', 'Tableau', 'DevOps',
#        'Oracle', 'API', 'Spring Boot', 'Confluence', 'Google Analytics',
#        'React Native', 'Hadoop', 'Notion', 'Slack', 'NoSQL', 'Jenkins',
#        'NodeJS', '데이터 분석', 'R', 'MSSQL', 'C#', 'Django', 'Restful API',
#        'Redis', 'OpenCV', 'Flask', 'RDBMS', 'Golang', 'VueJS', 'FastAPI',
#        'GitLab', 'SAP', 'Figma', 'JPA', 'NumPy', 'PHP', 'Vue.JS',
#        'Scikit-Learn', 'Data Analysis', 'NLP', 'Nest.js', 'Scala', 'ML',
#        'Redux', 'Google Cloud Platform', 'BI', '데이터베이스 관리', 'MVVM',
#        'GraphQL', 'ObjectiveC', 'CUDA', '데이터베이스', 'HTML5', 'Apache',
#        'Product Management ', '인공 지능', '전자정부프레임워크', 'OpenStack', 'REST',
#        '백엔드 개발', 'SAP MM', 'SAP FI', '.NET', '프론트엔드 개발자', 'SQL 서버',
#        'SAP SD', 'CISA', 'ORM', '개발', 'Go', 'Ubuntu', '딥 러닝', 'Framer',
#        'ROS', 'Excel', 'Shell Scripting', 'RESTful WebServices',
#        'ExpressJS', 'FPGA', '정부 업무', 'BitBucket', '영어 실력', 'Power BI',
#        '모델링', '모델링 및 시뮬레이션', 'HTTP', 'VM웨어', '데이터베이스 설계', 'Agile',
#        'Shell', 'Apache Kafka', '기술 관리', 'DLP', 'Embedded Linux',
#        'Firebase', 'MS 오피스', 'DirectX', 'Datastage', 'SoC', 'Amplitude',
#        'CSS3', 'OpenGL', '데이터베이스 개발', 'ETL', 'OSS', '컴퓨터 비전', 'Xen',
#        'Xamarin', '설계', 'Citrix', 'PMP', 'Mac', 'Kubeflow', '의료 영상',
#        '데이터 과학', 'Neo4j', '연구 관리', 'SQL Azure', 'SQL DB2', '데이터 구조',
#        '데이터 입력', '데이터 통합', '연구 및 개발', '기술 개발', 'QlikView', '데이터 수집',
#        'Verilog', 'Perl', '연구 설계', 'ES6', '서버 관리', 'iOS 개발', 'SAS', 'Qt',
#        'SVN', 'Nginx', 'jQuery', 'Apache Spark', '소프트웨어 개발', 'Unity3D',
#        'UX', 'Flutter', 'Rust', '검증', '보안 관리', 'Redmine', 'WebGL', '서버',
#        '보안', '보안 교육', '카메라', 'GIS', 'RTL 설계', '3D', 'RedHat', '서비스 관리',
#        'VPN', '프로젝트 관리', '자연 언어 처리', 'Spa', 'JUnit', 'iBatis', '클라이언트 개발',
#        'RabbitMQ', 'Windows 서버', 'Angular', '웹 개발', 'RTL 코딩', '신호 처리',
#        '네트워크 개발', '제품 출시', '제품 전략', 'PowerPoint', '카산드라', 'Asana', '수학',
#        '펌웨어', 'Android Studio', 'EDA', 'CSS 자바 스크립트', 'MFC', 'Laravel',
#        'DICOM', 'CentOS', 'ITIL', '클라우드 응용 프로그램', 'UI 디자인', 'Tomcat',
#        'SASS', 'Svelte', 'AngularJS', 'Delphi', '시스템 관리', '백신', '프로젝트 실행',
#        'CISSP', 'Mixpanel', '서버 아키텍처', '정보 보안', '상품 기획', 'UNIX',
#        '기계 학습 (Machine Learning)', '보안 감사', 'AJAX', '프로젝트 계획', 'NAS',
#        '리팩토링', 'STL', '전략 분석', '전략 기획', '내시경', 'FPGA 프로토 타이핑', 'Shader',
#        '차량', 'CAM', '공차 분석', 'Embedded C', '운영체제', 'TCL', 'STP', 'Xilinx',
#        '알고리즘 개발', '시장 조사', 'QA 엔지니어링', '팀 관리', 'GIS 응용 프로그램', 'GIS 시스템',
#        'WPF', '리더십 개발', '팀 빌딩', 'Leadership', '시스템 구조', '네비게이션 시스템',
#        'iOS 디자인', '프로그램 관리', '모바일 게임', 'Bash', 'JSP', '모바일 게임 개발',
#        'Spine', '재무 제표', '경영 관리', 'B2C', '페르소나', 'ABAP', '콘텐츠 제작',
#        'ASP .NET', 'Clojure', '솔루션 개발', '도메인 관리', '라이브러리 관리', '보안 정책',
#        'SPSS', 'HP', '정보관리', '분석능력', 'ERP 소프트웨어', '인프라', 'CAD', '의료 산업',
#        'EC2', 'JSP 개발', 'GLSL', 'SAP ERP', 'OLAP', '소켓', 'Scripting',
#        'IaaS', 'Data Guard', 'ORCAD', 'PLC', 'MES', '최적화', 'Ethereum',
#        'Atlassian JIRA', 'SSL', 'Apache 2', 'Bootstrap', '손익 계산서',
#        '네트워크 인프라', '네트워크 운영', 'Adobe XD', '네트워크 보안', 'IntelliJ IDEA',
#        '정부 계약', '재무 관리', 'JSF', '개인화', '학습 기술', '제품 기획', 'PaaS', '이미지 분석',
#        '이미지 처리', 'CCTV', '엑셀 모델', '컨설팅', '분석 문제 해결', '제안 개발', '비즈니스 분석',
#        'Ruby on Rails', 'MXNET', '로봇 프로그래밍', '전략적 사고', 'RTOS', 'SCM',
#        '서비스 프로세스', '재고 관리', 'DWDM', '구매', 'IT 관리', '카지노', 'IT 운영', '사무행정',
#        '게임 플레이', '급여 관리', '인사 관리', 'Microsoft Word', '사업 전략', '자산 관리',
#        '언어 학습', '다국어', '언어학', '지식 관리', '요구 사항 분석', '전략 컨설팅', '로봇',
#        '제안 작성', '제안 관리', '고객 경험', '투자', 'M&A', 'UX 기획', '앱 서버', 'CPA',
#        '구매 계약', '구매 프로세스', '임베디드 시스템', '유지보수', '안드로이드 SDK', '안드로이드 개발',
#        'Active Directory', '리눅스 서버', 'GCPs', 'RHEL', '방화벽', '고객 지원',
#        '기술 문서', '고객 관계', '기술 교육', '모바일 기술', '교육 기술', 'EnCase', '교육 관리',
#        '강의', 'BGP', 'PADS', 'Altium', '예측 모델링', '품질 보증', 'RPG',
#        'Processing', 'MMO', 'SQL 튜닝', 'Apple Software', 'DSL', '품질 관리',
#        'EPM', 'Puppet', 'SSIS', 'SSAS', 'PACS', 'HL7', 'SSO', '분석 서비스',
#        '학술 연구', '학술 출판', 'Web Socket', '반도체', '보드 개발', 'PCB 레이아웃 설계',
#        'Unreal Engine', 'EMR', 'CodeIgniter', 'WinForm', 'Simulink',
#        'Visual Studio Code', 'Rx', 'CRM', 'ASIC', 'VHDL', 'RTL 검증', 'GUI',
#        '테스트 실행', 'VBA', 'API 개발', '데이터 마트', 'IPS', 'Memcached', '복제',
#        '컴파일러', '금융', 'GPU', '임베디드 소프트웨어', 'SPICE', 'HTML 5', '소프트웨어 공학',
#        '컴퓨터 공학', 'RESTful Architecture', 'OOP', 'WebSphere MQ'],
#       dtype=object)

# %% [markdown]
# - 무의미한 stack 제거, 바꿀 stack명 변경

# %%
# 삭제 할 스택 명 
del_stack = ['데이터 분석', 'Data Analysis', '검증', '카메라', '프로젝트', '정부', '제품', '보안', 'SAP',
             'Leadership', '네비게이션', '금융', 'CCTV', '수학', '콘텐츠', '개인화', '학습', '최적화',
             '인프라', '강의', '학술', '반도체', '의료', '고객', '문서', '해결', '교육', '과학', '관리',
             '분석', '모델링', 'RTL', '펌웨어', '개발', '조사', 'SCM', '유지보수', '설계', '재무 제표', '차량',
             '기획', '컴파일러', '소켓', '운영', '작성', '컨설팅', '사무', 'FPGA', '공학', '로봇', '은행', '재무',
             '사업', '카지노', '플레이', '빌딩', '시장', '백 오피스', '임베디드', '손익', '신용', '테스트',
             '리팩토링', '백신', '구조', '데이터', '통계', 'QA 엔지니어링', 'MVVM', 'Product Management', 'EDA', 'API', 'DevOps', 'Agile', ]

# 바꿀 스택 명
change_stack = {'RESTful WebServices':'RESTful API', 'RESTful Architecture':'RESTful API', 'REST':'RESTful API',
                'Excel':'MS Office', '프론트엔드 개발자':'Web', '백엔드 개발':'Web', '인공 지능':'AI', '영어 실력':'제2외국어', '데이터베이스':'DB',
                '데이터베이스 관리':'DB', '딥 러닝':'ML/DL', '컴퓨터 비전':'OpenCV', 'SQL 서버':'SQL', 'MS 오피스':'MS Office',
                'iOS 개발':'iOS', '데이터베이스 설계':'DB', '데이터베이스 개발':'DB', '카산드라':'Cassandra', '웹 개발':'Web',
                'SQL DB2':'DB2', '엑셀 모델':'MS Office', 'GIS 시스템':'GIS', 'GIS 응용 시스템':'GIS', 'GIS 응용 프로그램':'GIS',
                '기계 학습 (Machine Learning)':'ML/DL', '모바일 게임 개발':'Mobile', '모바일 게임':'Mobile',
                'Microsoft Word':'MS Office', '다국어':'제2외국어', '앱 서버':'Mobile', '리눅스 서버':'Linux', '클라우드 응용 프로그램':'Cloud',
                '안드로이드 개발':'Android', '안드로이드 SDK':'Android', 'EC2':'AWS', '모바일 기술':'Mobile',
                'CSS3':'CSS', 'iOS 디자인':'iOS', '서버 아키텍처':'OS', 'PowerPoint':'MS Office', 'HTML 5':'HTML',
                '데이터 마트':'DB', '이미지 처리':'ML/DL', '신호 처리':'ML/DL', 'Android Studio':'Android',
                '자연 언어 처리':'ML/DL', 'ML':'ML/DL', 'UI 디자인':'UX/UI', 'UX':'UX/UI', 'DWDM':'DB', 'HTML5':'HTML',
                'Golang':'Go', 'Apple Software':'iOS', '언어학':'제2외국어', '서버':'Server', 'C / C++':'C/C++', 'Embeded C':'C/C++', 'C++':'C/C++', 'C':'C/C++',
                'Embedded Linux':'Linux', 'GCP':'Google Cloud Platform', 'Apache 2':'Apache', 'Apache Spark':'Spark', 'Apache Kafka':'Kafka'}

for k, v in change_stack.items():
    stacks_count.loc[stacks_count['stack'] == k, 'stack'] = v

# 제거 할 스택이 포함 된 경우 -> 스택명을 'delete'로 변환
for i in del_stack:
    stacks_count.loc[stacks_count['stack'].str.contains(i), 'stack'] = 'delete'

stacks_count['stack'].unique()
# Out:
# array(['Python', 'AWS', 'Git', 'JavaScript', 'Java', 'SQL', 'React',
#        'MySQL', 'Docker', 'Pytorch', 'TypeScript', 'Linux', 'Github',
#        'Spring Framework', 'Tensorflow', 'C/C++', 'Node.js', 'HTML',
#        'PostgreSQL', 'Kubernetes', 'Kotlin', 'Android', 'JIRA',
#        'Google Cloud Platform', 'CSS', 'iOS', 'Swift', 'MongoDB',
#        'Next.js', 'Azure', 'React.js', 'Spark', 'ElasticSearch',
#        'Tableau', 'delete', 'Oracle', 'Spring Boot', 'Confluence',
#        'Google Analytics', 'React Native', 'Hadoop', 'Notion', 'Slack',
#        'NoSQL', 'Jenkins', 'NodeJS', 'R', 'MSSQL', 'C#', 'Django',
#        'Redis', 'OpenCV', 'Flask', 'RDBMS', 'Go', 'VueJS', 'GitLab',
#        'Figma', 'JPA', 'NumPy', 'PHP', 'Vue.JS', 'Scikit-Learn', 'NLP',
#        'Nest.js', 'Scala', 'ML/DL', 'Redux', 'BI', 'DB', 'GraphQL',
#        'ObjectiveC', 'CUDA', 'Apache', 'AI', 'OpenStack', 'Web', '.NET',
#        'CISA', 'ORM', 'Ubuntu', 'Framer', 'ROS', 'MS Office',
#        'Shell Scripting', 'ExpressJS', 'BitBucket', '제2외국어', 'Power BI',
#        'HTTP', 'VM웨어', 'Shell', 'Kafka', 'DLP', 'Firebase', 'DirectX',
#        'Datastage', 'SoC', 'Amplitude', 'OpenGL', 'ETL', 'OSS', 'Xen',
#        'Xamarin', 'Citrix', 'PMP', 'Mac', 'Kubeflow', 'Neo4j',
#        'SQL Azure', 'DB2', 'QlikView', 'Verilog', 'Perl', 'ES6', 'SAS',
#        'Qt', 'SVN', 'Nginx', 'jQuery', 'Unity3D', 'UX/UI', 'Flutter',
#        'Rust', 'Redmine', 'WebGL', 'Server', 'GIS', '3D', 'RedHat', 'VPN',
#        'Spa', 'JUnit', 'iBatis', 'RabbitMQ', 'Windows 서버', 'Angular',
#        'Cassandra', 'Asana', 'CSS 자바 스크립트', 'MFC', 'Laravel', 'DICOM',
#        'CentOS', 'ITIL', 'Cloud', 'Tomcat', 'SASS', 'Svelte', 'AngularJS',
#        'Delphi', 'CISSP', 'Mixpanel', 'OS', 'UNIX', 'AJAX', 'NAS', 'STL',
#        '내시경', 'Shader', 'CAM', 'Embedded C', 'TCL', 'STP', 'Xilinx',
#        'WPF', 'Mobile', 'Bash', 'JSP', 'Spine', 'B2C', '페르소나', 'ABAP',
#        'ASP .NET', 'Clojure', 'SPSS', 'HP', 'ERP 소프트웨어', 'CAD', 'GLSL',
#        'OLAP', 'Scripting', 'IaaS', 'Data Guard', 'ORCAD', 'PLC', 'MES',
#        'Ethereum', 'Atlassian JIRA', 'SSL', 'Bootstrap', 'Adobe XD',
#        'IntelliJ IDEA', 'JSF', 'PaaS', 'Ruby on Rails', 'MXNET', '전략적 사고',
#        'RTOS', '서비스 프로세스', '구매', '투자', 'M&A', 'CPA', '구매 계약', '구매 프로세스',
#        'Active Directory', 'GCPs', 'RHEL', '방화벽', 'EnCase', 'BGP', 'PADS',
#        'Altium', '품질 보증', 'RPG', 'Processing', 'MMO', 'SQL 튜닝', 'DSL',
#        'EPM', 'Puppet', 'SSIS', 'SSAS', 'PACS', 'HL7', 'SSO',
#        'Web Socket', 'Unreal Engine', 'EMR', 'CodeIgniter', 'WinForm',
#        'Simulink', 'Visual Studio Code', 'Rx', 'CRM', 'ASIC', 'VHDL',
#        'GUI', 'VBA', 'IPS', 'Memcached', '복제', 'GPU', 'SPICE', 'OOP',
#        'WebSphere MQ'], dtype=object)

# %% [markdown]
# - 'CSS 자바 스크립트' 스택명의 경우 -> CSS, JavaScripts에 각각 하나씩 추가

# %%
stacks_count.loc[stacks_count['stack'] == 'CSS 자바 스크립트']
# Out:
#            stack  count
# 211  CSS 자바 스크립트      4

# %%
stacks_count.loc[(stacks_count['stack'] == 'CSS') | (stacks_count['stack'] == 'JavaScript')]
# Out:
#           stack  count
# 3    JavaScript    192
# 24          CSS     61
# 132         CSS      8

# %%
stacks_count = stacks_count.groupby('stack', sort=False).sum().reset_index()
stacks_count.loc[(stacks_count['stack'] == 'CSS') | (stacks_count['stack'] == 'JavaScript'), 'count'] += 4

# %%
stacks_count.loc[(stacks_count['stack'] == 'CSS') | (stacks_count['stack'] == 'JavaScript')]
# Out:
#          stack  count
# 3   JavaScript    196
# 24         CSS     73

# %%
stacks_count.loc[stacks_count['stack'] == 'CSS 자바 스크립트', 'stack'] = 'delete'

# %%
# 제거 할 스택 'delete'를 제외 한 나머지 확인

stacks_final = stacks_count.loc[stacks_count['stack'] != 'delete'].reset_index(drop=True)
stacks_final['stack'].unique()
# Out:
# array(['Python', 'AWS', 'Git', 'JavaScript', 'Java', 'SQL', 'React',
#        'MySQL', 'Docker', 'Pytorch', 'TypeScript', 'Linux', 'Github',
#        'Spring Framework', 'Tensorflow', 'C/C++', 'Node.js', 'HTML',
#        'PostgreSQL', 'Kubernetes', 'Kotlin', 'Android', 'JIRA',
#        'Google Cloud Platform', 'CSS', 'iOS', 'Swift', 'MongoDB',
#        'Next.js', 'Azure', 'React.js', 'Spark', 'ElasticSearch',
#        'Tableau', 'Oracle', 'Spring Boot', 'Confluence',
#        'Google Analytics', 'React Native', 'Hadoop', 'Notion', 'Slack',
#        'NoSQL', 'Jenkins', 'NodeJS', 'R', 'MSSQL', 'C#', 'Django',
#        'Redis', 'OpenCV', 'Flask', 'RDBMS', 'Go', 'VueJS', 'GitLab',
#        'Figma', 'JPA', 'NumPy', 'PHP', 'Vue.JS', 'Scikit-Learn', 'NLP',
#        'Nest.js', 'Scala', 'ML/DL', 'Redux', 'BI', 'DB', 'GraphQL',
#        'ObjectiveC', 'CUDA', 'Apache', 'AI', 'OpenStack', 'Web', '.NET',
#        'CISA', 'ORM', 'Ubuntu', 'Framer', 'ROS', 'MS Office',
#        'Shell Scripting', 'ExpressJS', 'BitBucket', '제2외국어', 'Power BI',
#        'HTTP', 'VM웨어', 'Shell', 'Kafka', 'DLP', 'Firebase', 'DirectX',
#        'Datastage', 'SoC', 'Amplitude', 'OpenGL', 'ETL', 'OSS', 'Xen',
#        'Xamarin', 'Citrix', 'PMP', 'Mac', 'Kubeflow', 'Neo4j',
#        'SQL Azure', 'DB2', 'QlikView', 'Verilog', 'Perl', 'ES6', 'SAS',
#        'Qt', 'SVN', 'Nginx', 'jQuery', 'Unity3D', 'UX/UI', 'Flutter',
#        'Rust', 'Redmine', 'WebGL', 'Server', 'GIS', '3D', 'RedHat', 'VPN',
#        'Spa', 'JUnit', 'iBatis', 'RabbitMQ', 'Windows 서버', 'Angular',
#        'Cassandra', 'Asana', 'MFC', 'Laravel', 'DICOM', 'CentOS', 'ITIL',
#        'Cloud', 'Tomcat', 'SASS', 'Svelte', 'AngularJS', 'Delphi',
#        'CISSP', 'Mixpanel', 'OS', 'UNIX', 'AJAX', 'NAS', 'STL', '내시경',
#        'Shader', 'CAM', 'Embedded C', 'TCL', 'STP', 'Xilinx', 'WPF',
#        'Mobile', 'Bash', 'JSP', 'Spine', 'B2C', '페르소나', 'ABAP',
#        'ASP .NET', 'Clojure', 'SPSS', 'HP', 'ERP 소프트웨어', 'CAD', 'GLSL',
#        'OLAP', 'Scripting', 'IaaS', 'Data Guard', 'ORCAD', 'PLC', 'MES',
#        'Ethereum', 'Atlassian JIRA', 'SSL', 'Bootstrap', 'Adobe XD',
#        'IntelliJ IDEA', 'JSF', 'PaaS', 'Ruby on Rails', 'MXNET', '전략적 사고',
#        'RTOS', '서비스 프로세스', '구매', '투자', 'M&A', 'CPA', '구매 계약', '구매 프로세스',
#        'Active Directory', 'GCPs', 'RHEL', '방화벽', 'EnCase', 'BGP', 'PADS',
#        'Altium', '품질 보증', 'RPG', 'Processing', 'MMO', 'SQL 튜닝', 'DSL',
#        'EPM', 'Puppet', 'SSIS', 'SSAS', 'PACS', 'HL7', 'SSO',
#        'Web Socket', 'Unreal Engine', 'EMR', 'CodeIgniter', 'WinForm',
#        'Simulink', 'Visual Studio Code', 'Rx', 'CRM', 'ASIC', 'VHDL',
#        'GUI', 'VBA', 'IPS', 'Memcached', '복제', 'GPU', 'SPICE', 'OOP',
#        'WebSphere MQ'], dtype=object)

# %%
stacks_final.loc[len(stacks_final)] = ['Airflow', 0]
stacks_final
# Out:
#             stack  count
# 0          Python    517
# 1             AWS    357
# 2             Git    218
# 3      JavaScript    196
# 4            Java    187
# ..            ...    ...
# 241           GPU      1
# 242         SPICE      1
# 243           OOP      1
# 244  WebSphere MQ      1
# 245       Airflow      0
#
# [246 rows x 2 columns]

# %% [markdown]
# - 우대사항에서 스택 추출
#     - stack의 값이 nan인 경우 우대사항에서 stack 추출
#     - ex : stack이 Nan, 우대사항이 'MongoDB 경험이 있으시면 더 좋습니다' 인경우 'MongoDB' 추출하여 stack에 추가

# %%
stacks_list = stacks_final['stack'].to_list()

# %%
# stack이 NaN인 값들의 우대사항만 추출

no_stack = all_pre.loc[all_pre['stack'].isnull()]
no_stack = no_stack[['preference']].reset_index(drop=True)
no_stack.dropna(axis=0, how='all', inplace=True)
no_stack = no_stack[['preference']].reset_index(drop=True)
no_stack
# Out:
#                                             preference
# 0    • DB 모니터링 프로세스 구축 및 관제 경험이 있는 분\n• SQLD , DAP,...
# 1    - 전형절차\n • 서류전형 ＞ 필기전형(SKCT) ＞ 면접전형 ＞ 처우협의 ＞ 채...
# 2    - 전형절차\n • 서류전형 ＞ 필기전형(SKCT) ＞ 면접전형 ＞ 처우협의 ＞ 채...
# 3    • 게임 서비스 DB 작업 경험이 있으신 분\n• 대규모 데이터 기반 DB 작업 경...
# 4    • MongoDB 경험이 있으시면 더 좋습니다.\n• 금융/핀테크 및 커머스 서비스...
# ..                                                 ...
# 449  • 휴가사용은 자유롭게 + (무급) 휴가 무제한\n• 동료와 원활한 협업을 위해 1...
# 450  - 슬랙(Slack), 노션(Notion), 지라(Jira), 피그마(Figma) ...
# 451  [이런 분이라면 더 좋아요!]\n• AWS/GCP 등 클라우드 환경에서 데이터 플랫...
# 452  - 데이터 사이언스 관련 전공자\n- 퍼블릭 클라우드 환경 (GCP, AWS, Az...
# 453  • ML 관련 Top-tier 학회 및 저널 Publication 실적\n(Neur...
#
# [454 rows x 1 columns]

# %%
import re

for i in stacks_list: # 이전에 추출한 스택리스트를 for문으로 하나씩 가져옴
    # i가 정규 표현식 패턴이라면 이스케이프 처리
    i_pattern = re.escape(i)

    # 우대사항에 스택리스트의 글자가 포함된 수먼쿰 i_count에 더함
    i_count = no_stack['preference'].str.contains(i_pattern).sum()
    # i_count 만큼 스택리스트의 해당 스택에 더해줌 
    stacks_final.loc[stacks_final['stack'] == i, 'count'] += i_count 
stacks_final
# Out:
#         stack  count
# 0      Python    568
# 1         AWS    420
# 2         Git    240
# 3  JavaScript    200
# 4        Java    212
# 5         SQL    248
# 6       React    190
# 7       MySQL    181
# 8      Docker    182
# 9     Pytorch    151

# %%
stacks_final.sort_values('count',ascending = False).head(10)
# Out:
#          stack  count
# 0       Python    568
# 1          AWS    420
# 5          SQL    248
# 2          Git    240
# 4         Java    212
# 3   JavaScript    200
# 15       C/C++    200
# 6        React    190
# 8       Docker    182
# 7        MySQL    181

# %%
all_stack = stacks_final

# %%
# all_stack.to_csv("all_stack.csv", encoding='utf-8', index = False)

# %% [markdown]
# # 각 직군 별 우대사항, 스택 합본 생성

# %% [markdown]
# - 함수 생성

# %%
def count_maker(df):
    stacks = df.loc[~(df['stack'].isnull()), 'stack'].str.split('\n', regex=True)

    stack_list = []
    for i in stacks:
        for j in i:
            stack_list.append(j)
    stacks_count = pd.DataFrame(pd.Series(data=stack_list).value_counts()).reset_index()
    stacks_count.columns = ['stack', 'count']

    del_stack = ['데이터 분석', 'Data Analysis', '검증', '카메라', '프로젝트', '정부', '제품', '보안', 'SAP',
                'Leadership', '네비게이션', '금융', 'CCTV', '수학', '콘텐츠', '개인화', '학습', '최적화',
                '인프라', '강의', '학술', '반도체', '의료', '고객', '문서', '해결', '교육', '과학', '관리',
                '분석', '모델링', 'RTL', '펌웨어', '개발', '조사', 'SCM', '유지보수', '설계', '재무 제표', '차량',
                '기획', '컴파일러', '소켓', '운영', '작성', '컨설팅', '사무', 'FPGA', '공학', '로봇', '은행', '재무',
                '사업', '카지노', '플레이', '빌딩', '시장', '백 오피스', '임베디드', '손익', '신용', '테스트',
                '리팩토링', '백신', '구조', '데이터', '통계', 'QA 엔지니어링', 'MVVM', 'Product Management', 'EDA', 'API', 'DevOps', 'Agile', ]

    change_stack = {'RESTful WebServices':'RESTful API', 'RESTful Architecture':'RESTful API', 'REST':'RESTful API',
                    'Excel':'MS Office', '프론트엔드 개발자':'Web', '백엔드 개발':'Web', '인공 지능':'AI', '영어 실력':'제2외국어', '데이터베이스':'DB',
                    '데이터베이스 관리':'DB', '딥 러닝':'ML/DL', '컴퓨터 비전':'OpenCV', 'SQL 서버':'SQL', 'MS 오피스':'MS Office',
                    'iOS 개발':'iOS', '데이터베이스 설계':'DB', '데이터베이스 개발':'DB', '카산드라':'Cassandra', '웹 개발':'Web',
                    'SQL DB2':'DB2', '엑셀 모델':'MS Office', 'GIS 시스템':'GIS', 'GIS 응용 시스템':'GIS', 'GIS 응용 프로그램':'GIS',
                    '기계 학습 (Machine Learning)':'ML/DL', '모바일 게임 개발':'Mobile', '모바일 게임':'Mobile',
                    'Microsoft Word':'MS Office', '다국어':'제2외국어', '앱 서버':'Mobile', '리눅스 서버':'Linux', '클라우드 응용 프로그램':'Cloud',
                    '안드로이드 개발':'Android', '안드로이드 SDK':'Android', 'EC2':'AWS', '모바일 기술':'Mobile',
                    'CSS3':'CSS', 'iOS 디자인':'iOS', '서버 아키텍처':'OS', 'PowerPoint':'MS Office', 'HTML 5':'HTML',
                    '데이터 마트':'DB', '이미지 처리':'ML/DL', '신호 처리':'ML/DL', 'Android Studio':'Android',
                    '자연 언어 처리':'ML/DL', 'ML':'ML/DL', 'UI 디자인':'UX/UI', 'UX':'UX/UI', 'DWDM':'DB', 'HTML5':'HTML',
                    'Golang':'Go', 'Apple Software':'iOS', '언어학':'제2외국어', '서버':'Server', 'C / C++':'C/C++', 'Embeded C':'C/C++', 'C++':'C/C++', 'C':'C/C++',
                    'Embedded Linux':'Linux', 'GCP':'Google Cloud Platform', 'Apache 2':'Apache', 'Apache Spark':'Spark', 'Apache Kafka':'Kafka'}

    for k, v in change_stack.items():
        stacks_count.loc[stacks_count['stack'] == k, 'stack'] = v

    for i in del_stack:
        stacks_count.loc[stacks_count['stack'].str.contains(i), 'stack'] = 'delete'




    return stacks_count

# %% [markdown]
# - DE

# %%
DE_stack = count_maker(DE)
# MLE_stack = count_maker(MLE)
# Data_ANL_stack = count_maker(Data_ANL)
# Data_SCI_stack = count_maker(Data_SCI)

# %%
def stack_maker(job_stack, job):
    if sum(job_stack['stack'] == 'CSS 자바 스크립트') != 0:
        count = job_stack.loc[job_stack['stack'] == 'CSS 자바 스크립트']['count'].values[0]
        job_stack = job_stack.groupby('stack', sort=False).sum().reset_index()
        job_stack.loc[(job_stack['stack'] == 'CSS') | (job_stack['stack'] == 'JavaScript'), 'count'] += count
        job_stack.loc[job_stack['stack'] == 'CSS 자바 스크립트', 'stack'] = 'delete'
    else :
        job_stack = job_stack.groupby('stack', sort=False).sum().reset_index()

    stacks_final = job_stack.loc[job_stack['stack'] != 'delete'].reset_index(drop=True)
    stacks_list = stacks_final['stack'].to_list()

    no_stack = job.loc[job['stack'].isnull()]
    no_stack = no_stack[['preference']].reset_index(drop=True)
    no_stack.dropna(axis=0, how='all', inplace=True)
    no_stack = no_stack[['preference']].reset_index(drop=True)
    no_stack

    for i in stacks_list:
        i_pattern = re.escape(i)
        i_count = no_stack['preference'].str.contains(i_pattern).sum()
        stacks_final.loc[stacks_final['stack'] == i, 'count'] += i_count

    return stacks_final

# %%
DE_stack = stack_maker(DE_stack, DE)
DE_stack.head(10)
# Out:
#         stack  count
# 0      Python    265
# 1         AWS    236
# 2        Java    121
# 3       MySQL    109
# 4  JavaScript    105
# 5         SQL    136
# 6         Git    106
# 7       React     93
# 8      Docker     89
# 9       Linux     81

# %%
# DE_stack.to_csv("DE_stack.csv", encoding='utf-8', index = False)

# %% [markdown]
# - MLE

# %%
MLE_stack = count_maker(MLE)
MLE_stack
# Out:
#           stack  count
# 0        Python    178
# 1           AWS     93
# 2       Pytorch     80
# 3           Git     75
# 4    Tensorflow     58
# ..          ...    ...
# 233      Svelte      1
# 234    Simulink      1
# 235      delete      1
# 236      delete      1
# 237      delete      1
#
# [238 rows x 2 columns]

# %%
MLE_stack = stack_maker(MLE_stack, MLE)
MLE_stack.head(10)
# Out:
#         stack  count
# 0      Python    183
# 1         AWS    105
# 2     Pytorch     81
# 3         Git     81
# 4  Tensorflow     63
# 5       React     58
# 6       C/C++    113
# 7  JavaScript     56
# 8      Docker     60
# 9        Java     52

# %%
# MLE_stack.to_csv("MLE_stack.csv", encoding='utf-8', index = False)

# %% [markdown]
# - Data ANL

# %%
ANL_stack = count_maker(Data_ANL)
ANL_stack
# Out:
#         stack  count
# 0         SQL     17
# 1      Python     10
# 2   MS Office     10
# 3      delete     10
# 4        JIRA     10
# ..        ...    ...
# 93      제2외국어      1
# 94      제2외국어      1
# 95     delete      1
# 96        ETL      1
# 97       Java      1
#
# [98 rows x 2 columns]

# %%
ANL_stack = stack_maker(ANL_stack, Data_ANL)
ANL_stack.head(10)
# Out:
#               stack  count
# 0               SQL     28
# 1            Python     20
# 2         MS Office     19
# 3              JIRA     11
# 4  Google Analytics     13
# 5        Confluence      9
# 6           Tableau     27
# 7            Notion      7
# 8             Slack      6
# 9             Figma      6

# %%
# ANL_stack.to_csv("ANL_stack.csv", encoding='utf-8', index = False)

# %% [markdown]
# - SCI

# %%
SCI_stack = count_maker(Data_SCI)
SCI_stack
# Out:
#           stack  count
# 0        Python     88
# 1           AWS     62
# 2           Git     43
# 3    JavaScript     36
# 4         React     36
# ..          ...    ...
# 176        UNIX      1
# 177       Shell      1
# 178       Cloud      1
# 179      delete      1
# 180      Delphi      1
#
# [181 rows x 2 columns]

# %%
SCI_stack = stack_maker(SCI_stack, Data_SCI)
SCI_stack.head(10)
# Out:
#         stack  count
# 0      Python    100
# 1         AWS     74
# 2         Git     49
# 3  JavaScript     38
# 4       React     39
# 5         SQL     45
# 6        Java     38
# 7       MySQL     32
# 8      Docker     33
# 9  TypeScript     29

# %%
# SCI_stack.to_csv("SCI_stack.csv", encoding='utf-8', index = False)

# %% [markdown]
# # 워드클라우드 생성

# %%
from wordcloud import WordCloud
import matplotlib.pyplot as plt

# 상위 x가지 키워드로 워드클라우드 생성하는 함수 생성
def WC_maker(df, x = None): # 데이터 프레임 및 count 갯수 지정
    # df : 1행은 워드클라우드로 보여줄 단어, 2행은 단어의 빈도수로 구성된 데이터 프레임
    # x : 워드클라우드로 나타낼 상위 x개 데이터
    if x == None:
        data = dict(zip(df.iloc[:,0].tolist(), df.iloc[:,1].tolist()))
    else: 
        data = dict(zip(df.iloc[:,0].head(x).tolist(), df.iloc[:,1].head(x).tolist())) 

    data
    wc = WordCloud(font_path ='C:/Windows/Fonts/Hancom Gothic Regular.ttf',            #폰트 
                background_color='white',                              #배경색
                width=800, height=600 ,                                #사이즈설정
                max_words=200)                                         #단어갯수

    cloud = wc.generate_from_frequencies(data)                            #사전형태 데이터

    plt.figure(figsize=(10,10))                                           #프레임 사이즈설정
    plt.axis('off')                                                       #테두리 선 없애기
    plt.imshow(cloud,interpolation="bilinear")

# %%
# 전체직군 통합 워드클라우드
WC_maker(all_stack)

# %%
# 데이터 분석가 워드클라우드
WC_maker(ANL_stack)

# %%
# 데이터 엔지니어 워드클라우드
WC_maker(DE_stack)

# %%
# 머신러닝 엔지니어 워드클라우드
WC_maker(MLE_stack)

# %%
# 데이터 사이언티스트 워드클라우드
WC_maker(SCI_stack)

# %% [markdown]
# # 태블로용 데이터 생성

# %%
# 직업명 컬럼 추가
DE_stack['job'] = 'DE'
ANL_stack['job'] = 'ANL'
MLE_stack['job'] = 'MLE'
SCI_stack['job'] = 'SCI'

# %%
all_job_stack = pd.concat([DE_stack, ANL_stack, MLE_stack, SCI_stack]).reset_index(drop = True)
all_job_stack
# Out:
#           stack  count  job
# 0        Python    265   DE
# 1           AWS    236   DE
# 2          Java    121   DE
# 3         MySQL    109   DE
# 4    JavaScript    105   DE
# ..          ...    ...  ...
# 530       Asana      1  SCI
# 531        UNIX      1  SCI
# 532       Shell      2  SCI
# 533       Cloud      2  SCI
# 534      Delphi      1  SCI
#
# [535 rows x 3 columns]

# %%
# all_job_stack.to_excel('all_job_stack.xlsx', index = False)
